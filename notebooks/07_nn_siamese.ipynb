# %% [markdown]
# ## 7) Neural‐network extension: Siamese DTW

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from importlib import reload
from sklearn.model_selection import StratifiedShuffleSplit
import tensorflow as tf
to_categorical = tf.keras.utils.to_categorical

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

import src.nn_utils.data as data_utils
import src.nn_utils.model as model_utils
import src.nn_utils.training as train_utils
import src.evaluation.evaluation as ev
from src.evaluation.evaluation import _dtw_distance_np

reload(data_utils); reload(model_utils); reload(train_utils); reload(ev)

PAIRS_PATH = project_root / "data" / "pairs_meta.parquet"
CATALOG    = project_root / "data" / "processed" / "catalog.parquet"    # ⟵ use 01’s catalog
PROC_ROOT  = project_root / "data" / "processed"
FIG_DIR    = project_root / "figures"; FIG_DIR.mkdir(parents=True, exist_ok=True)

# Reproducibility (optional)
np.random.seed(42)
tf.random.set_seed(42)

SEQ_LEN    = 100
N_FEATURES = 9

# 7.1) Load or rebuild pairwise pairs
if PAIRS_PATH.exists():
    pairs_df = pd.read_parquet(PAIRS_PATH)
    assert {"pathA","pathB","label"}.issubset(pairs_df.columns), "pairs_meta missing required columns"
else:
    print("pairs_meta.parquet not found → rebuilding from catalog...")
    # IMPORTANT: fix the import to match your actual filename
    from src.pairing.make_pairs import generate_pairs, balance_subsample   # rename file if needed
    cat = pd.read_parquet(CATALOG)

    # Build a single 'path' column the generator expects
    if "path_lf" in cat.columns:
        df_loc = cat[["path_lf"]].rename(columns={"path_lf":"path"}).copy()
    elif "file_path" in cat.columns:
        # older catalogs sometimes used a different name
        df_loc = cat[["file_path"]].rename(columns={"file_path":"path"}).copy()
    else:
        raise RuntimeError("Catalog must contain 'path_lf' or 'file_path'.")

    pairs_df = generate_pairs(df_loc, path_col="path", weak_forgery=False)
    pairs_df = balance_subsample(pairs_df, max_pairs=200_000, random_state=42)
    pairs_df.to_parquet(PAIRS_PATH, index=False)
    print(f"✓ wrote {len(pairs_df):,} pairs → {PAIRS_PATH}")

# 7.2) Load sequences (resampled) for Siamese training
X1, X2, y = data_utils.load_siamese_data(pairs_df, PROC_ROOT, SEQ_LEN)

# %% 7.3) One stratified split to keep indices aligned
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
(train_idx, test_idx), = sss.split(np.zeros(len(y)), y)

X1_tr, X1_te = X1[train_idx], X1[test_idx]
X2_tr, X2_te = X2[train_idx], X2[test_idx]
y_tr,  y_te  = y[train_idx],  y[test_idx]

y_tr_cat = to_categorical(y_tr, num_classes=2)
y_te_cat = to_categorical(y_te, num_classes=2)

# %% 7.4) Build models
siamese_model = model_utils.build_siamese_dtw_model(
    sequence_length=SEQ_LEN,
    n_features=N_FEATURES,
    hidden_dims=(7,5),
    dtw_gamma=1.0,
    post_hidden=(16,8),
)
siamese_model.summary()

# Baseline NN on simple 18-dim features (mean over time per stream)
X1_avg = X1.mean(axis=1)   # (N, 9)
X2_avg = X2.mean(axis=1)   # (N, 9)
X_base = np.concatenate([X1_avg, X2_avg], axis=1)  # (N, 18)
X_base_tr, X_base_te = X_base[train_idx], X_base[test_idx]

baseline_model = model_utils.build_baseline_nn(input_dim=2*N_FEATURES, hidden_dims=(32,16))
baseline_model.summary()

# %% 7.5) Train
history_siamese = train_utils.train_siamese_model(
    siamese_model,
    X1_tr, X2_tr, y_tr_cat,
    batch_size=32,
    epochs=20,
    validation_split=0.2
)

history_baseline = baseline_model.fit(
    X_base_tr, y_tr_cat,
    batch_size=32,
    epochs=20,
    validation_split=0.2
)

# %% 7.6) Evaluate
y_pred_siam = siamese_model.predict([X1_te, X2_te])[:, 1]
df_siam = pd.DataFrame({"label": y_te, "score": y_pred_siam})
metrics_siam = ev.compute_metrics(df_siam.rename(columns={"score":"d_raw"}))
print(f"Siamese-DTW   → AUC={metrics_siam['auc']:.4f}, EER={metrics_siam['eer']:.4f} @ thr={metrics_siam['eer_threshold']:.5f}")

y_pred_base = baseline_model.predict(X_base_te)[:, 1]
df_base = pd.DataFrame({"label": y_te, "score": y_pred_base})
metrics_base = ev.compute_metrics(df_base.rename(columns={"score":"d_raw"}))
print(f"Baseline NN   → AUC={metrics_base['auc']:.4f}, EER={metrics_base['eer']:.4f} @ thr={metrics_base['eer_threshold']:.5f}")

# Classic (non-diff) DTW for reference
dists = np.array([_dtw_distance_np(a, b) for a, b in zip(X1_te, X2_te)])
scores_dtw = -dists
df_dtw = pd.DataFrame({"label": y_te, "score": scores_dtw})
metrics_dtw = ev.compute_metrics(df_dtw.rename(columns={"score":"d_raw"}))
print(f"Classic DTW   → AUC={metrics_dtw['auc']:.4f}, EER={metrics_dtw['eer']:.4f} @ thr={metrics_dtw['eer_threshold']:.5f}")

# %% 7.7) ROC / DET
fig, ax = plt.subplots(figsize=(6,6))
ax.plot(metrics_siam["fpr"], metrics_siam["tpr"], label=f"Siamese-DTW (AUC={metrics_siam['auc']:.3f})")
ax.plot(metrics_base["fpr"], metrics_base["tpr"], label=f"Baseline NN (AUC={metrics_base['auc']:.3f})")
ax.plot(metrics_dtw["fpr"],  metrics_dtw["tpr"],  label=f"Classic DTW (AUC={metrics_dtw['auc']:.3f})")
ax.plot([0,1], [0,1], "k--")
ax.set_xlabel("False Positive Rate"); ax.set_ylabel("True Positive Rate"); ax.legend()
fig.savefig(FIG_DIR / "comparison_roc.png", dpi=300); plt.close(fig)

fig, ax = plt.subplots(figsize=(6,6))
ax.plot(metrics_siam["fpr"], 1 - metrics_siam["tpr"], label="Siamese-DTW")
ax.plot(metrics_base["fpr"], 1 - metrics_base["tpr"], label="Baseline NN")
ax.plot(metrics_dtw["fpr"],  1 - metrics_dtw["tpr"],  label="Classic DTW")
ax.set_xlabel("False Positive Rate"); ax.set_ylabel("Miss Rate (1 − TPR)"); ax.legend()
fig.savefig(FIG_DIR / "comparison_det.png", dpi=300); plt.close(fig)

# %% 7.8) Save models (Keras native format)
(project_root / "models").mkdir(exist_ok=True)
siamese_model.save(project_root / "models" / "siamese_final.keras")
baseline_model.save(project_root / "models" / "baseline_final.keras")
# Out:
# Model: "SiameseDTW"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ inputA (InputLayer) │ (None, 100, 9)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ inputB (InputLayer) │ (None, 100, 9)    │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_dense_0          │ (None, 100, 7)    │         70 │ inputA[0][0],     │
# │ (TimeDistributed)   │                   │            │ inputB[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ td_dense_1          │ (None, 100, 5)    │         40 │ td_dense_0[0][0], │
# │ (TimeDistributed)   │                   │            │ td_dense_0[1][0]  │
# ...
